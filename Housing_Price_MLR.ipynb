# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/Housing - Housing.csv')
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['mainroad']= label_encoder.fit_transform(df['mainroad'])
df['guestroom']= label_encoder.fit_transform(df['guestroom'])
df['basement']= label_encoder.fit_transform(df['basement'])
df['hotwaterheating']= label_encoder.fit_transform(df['hotwaterheating'])
df['airconditioning']= label_encoder.fit_transform(df['airconditioning'])
df['prefarea']= label_encoder.fit_transform(df['prefarea'])
df['furnishingstatus']= label_encoder.fit_transform(df['furnishingstatus'])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
x=df[['area','bedrooms','bathrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus']]
y=df[['price']]

# %%
print(x)
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
print(y)
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(x_test[0:20])
# Out:
#       area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 239   4000         3          1        2         1          0         0
# 113   9620         3          1        1         1          0         1
# 325   3460         4          1        2         1          0         0
# 66   13200         2          1        1         1          0         1
# 479   3660         4          1        2         0          0         0
# 103   6350         3          2        3         1          1         0
# 386   3850         3          1        1         1          0         0
# 480   3480         3          1        2         0          0         0
# 400   3512         2          1        1         1          0         0
# 37    9000         4          2        4         1          0         0
# 71    6000         4          2        4         1          0         0
# 329   3960         3          1        2         1          0         0
# ...

# %%
print(y_test)
# Out:
#        price
# 239  4585000
# 113  6083000
# 325  4007500
# 66   6930000
# 479  2940000
# ..       ...
# 76   6650000
# 132  5810000
# 311  4123000
# 464  3080000
# 155  5530000
#
# [109 rows x 1 columns]

# %%
y_pred=mlr.predict(x_test)
print(y_pred)
# Out:
# [[ 4019080.69890147]
#  [ 6258021.768564  ]
#  [ 4392719.13411047]
#  [ 7335082.21688194]
#  [ 2892857.56615675]
#  [ 7084655.57701774]
#  [ 3258634.73504731]
#  [ 3196499.16068631]
#  [ 3520106.01134941]
#  [ 8359610.28845465]
#  [ 6646926.36096856]
#  [ 3788844.63269237]
#  [ 3734072.96467981]
#  [ 4616010.40973202]
#  [ 3946124.94405792]
#  [ 2023177.4684687 ]
#  [ 3975554.48783028]
#  [ 3624716.9650089 ]
#  [ 3210282.74216168]
#  [ 4668411.38105794]
#  [ 5893719.66376515]
#  [ 6415683.83807236]
#  [ 4657036.55831934]
#  [ 2704096.11205267]
#  [ 5356909.86181449]
#  [ 5740682.56798041]
#  [ 5337586.47961082]
#  [ 5444859.96648234]
#  [ 5702144.57144375]
#  [ 5865872.30432732]
#  [ 3307327.30668416]
#  [ 6299491.02684292]
#  [ 7123479.95544321]
#  [ 2960326.86653052]
#  [ 4424323.19483818]
#  [ 5125081.85591294]
#  [ 4947693.93115736]
#  [ 3629027.81981122]
#  [ 2975421.52734786]
#  [ 3975089.54021919]
#  [ 8106313.95534003]
#  [ 5014658.87529549]
#  [ 6469749.69804857]
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6578047592637595

# %%
a=float(input("Enter the area : "))
b=int(input("Enter the number of bedrooms : "))
c= int(input("Enter the number of bathrooms : "))
d= int(input("Enter the number of stories : "))
e= int(input("mainroad yes=1 and no =0 : "))
f=int(input("whether there is a guestroom=1 or not=0 : "))
g=int(input("whether there is a basement=1 or not=0 : "))
h=int(input("whether there is a hotwaterheating=1 or not=0 : "))
i=int(input("whether there is a airconditioning=1 or not=0 : "))
j=int(input("enter the number of parking areas : "))
k=int(input("whether there is a prefarea=1 or not=0 : "))
l=int(input("whether there is a semifurnished=1 or furnished=0  or unfurnished=2 : "))
m=pd.DataFrame([[a,d,c,d,e,f,g,h,i,j,k,l]])
result=mlr.predict(m)
# Out:
# Enter the area : 4000
# Enter the number of bedrooms : 3
# Enter the number of bathrooms : 1
# Enter the number of stories : 2
# mainroad yes=1 and no =0 : 1
# whether there is a guestroom=1 or not=0 : 0
# whether there is a basement=1 or not=0 : 0
# whether there is a hotwaterheating=1 or not=0 : 0
# whether there is a airconditioning=1 or not=0 : 1
# enter the number of parking areas : 0
# whether there is a prefarea=1 or not=0 : 0
# whether there is a semifurnished=1 or furnished=0  or unfurnished=2 : 0
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Predicted price = ",result)
# Out:
# Predicted price =  [[4532530.94413375]]
